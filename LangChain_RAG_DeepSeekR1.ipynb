# %% [markdown]
# # Usando LangChain e RAG com DeepSeek R1

# %% [markdown]
# ## instalação de pré-requisitos

# %%
print("Instalando ChromaDB")
# !pip install chromadb | tail -1

print("Instalando Sentence Transformers")
# !pip install sentence-transformers | tail -1

print("Instalando pypdf")
# !pip install pypdf | tail -1

print("Instalando langchain")
# !pip install langchain | tail -1

print("Instalando langchain-community")
# !pip install langchain_community | tail -1

print("Instalando huggingface_hub")
# !pip install huggingface_hub | tail -1

print("Instalando langchain-huggingface")
# !pip install langchain_huggingface

print("Instalando transformers")
# !pip install transformers | tail -1
# Out:
# Instalando ChromaDB
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Instalando Sentence Transformers
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Instalando pypdf
# Successfully installed pypdf-5.3.0
# Instalando langchain
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Instalando langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain_community-0.3.18 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.0 typing-inspect-0.9.0
# Instalando huggingface_hub
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.1.31)
# Instalando transformers
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
from pypdf import PdfReader
import requests
import os
import chromadb
from chromadb.config import Settings
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## carregamento de dados
#
# The Little Prince (pdf)

# %%
def download_file(url, filename):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise an exception for bad status codes

        with open(filename, 'wb') as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"File '{filename}' downloaded successfully.")

    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")

# Example usage:
file_url = "https://blogs.ubc.ca/edcp508/files/2016/02/TheLittlePrince.pdf"
file_name = "TheLittlePrince.pdf"

if not os.path.exists(file_name):
  download_file(file_url, file_name)
else:
  print(f"File '{file_name}' already exists.")
# Out:
# File 'TheLittlePrince.pdf' downloaded successfully.

# %% [markdown]
# ## processar o pdf como texto

# %%
def process_pdf(file_path):
    reader = PdfReader(file_path)
    chunks = []
    file_name = file_path.split('/')[-1]  # Extrai o nome do arquivo

    for page_num in range(len(reader.pages)):
      page = reader.pages[page_num]
      text = page.extract_text()

      # Processamento de chunks
      chunk_size = 200  # Define o tamanho desejado dos chunks
      start_idx = 0
      end_idx = chunk_size

      chunk_id_counter = 0

      while start_idx < len(text):
          chunk = text[start_idx:end_idx]
          chunks.append({
              'id': f"{file_name}_page_{page_num + 1}_chunk_{chunk_id_counter}",
              'text': chunk,
              'metadata': {
                  'file_name': file_name,
                  'page': page_num + 1,
              },
          })
          start_idx = end_idx
          end_idx = min(end_idx + chunk_size, len(text))
          chunk_id_counter += 1

    return chunks

# %%
# model_name = 'all-mpnet-base-v2'
# embedder = SentenceTransformer(model_name)

from langchain.embeddings import HuggingFaceEmbeddings
embedder = HuggingFaceEmbeddings(
    # api_key="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",
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Process the PDF and get chunks
chunks = process_pdf(file_name)
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 9 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1024 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 
chunk_2
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_50_chunk_3
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_0
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_1
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_2
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_3
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_4
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_5
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_6
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_7
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_8
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_9
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_0
# ...
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_48_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_48_chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_48_chunk_10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_48_chunk_11
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_48_chunk_12
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_49_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_50_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_50_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_50_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_50_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_51_chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_52_chunk_10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_53_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_53_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_53_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_53_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_53_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_54_chunk_10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_55_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_56_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_56_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_56_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_56_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_56_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_56_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_57_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_58_chunk_10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_59_chunk_10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_60_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_61_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_61_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_62_chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_63_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_63_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_63_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_63_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: TheLittlePrince.pdf_page_64_chunk_6
# Chunks and metadata saved to collection 'little_prince'.

# %%
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFaceHub
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.text_splitter import CharacterTextSplitter

# %%
# Initialize ChromaDB client (assuming you've already created the collection)
persist_directory = "/content/chromadb"
client = chromadb.PersistentClient(path=persist_directory)
collection_name = "little_prince"
collection = client.get_collection(name=collection_name)

# Create a vectorstore from the Chroma collection
vectorstore = Chroma(collection_name=collection_name,
                     embedding_function=embedder,
                     persist_directory=persist_directory, client=client)

from langchain_huggingface.llms.huggingface_endpoint import HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    task='text-generation',
    model="deepseek-ai/DeepSeek-R1",
    max_new_tokens=100,
    temperature=0.5,
    huggingfacehub_api_token="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" # CHANGE TO A VALID FREE API KEY
)

import warnings
warnings.filterwarnings("ignore")

query = "Who is the prince?"

print("DIRECT (((DeepSeek R1))) APPLIED:\nQuestion: {query}\nAnswer: {result}".format(query=query, result=llm.invoke(query)) )

# Initialize the QA chain
qa_retriever = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever()
)

print("\n\n-------------------")

result = qa_retriever.run(query)
print("LangChain/RAG APPLIED OVER (((DeepSeek R1))):\nQuestion: {query}\nAnswer: {result}".format(query=query, result=result))
# Out:
# DIRECT (((DeepSeek R1))) APPLIED:
# Question: Who is the prince?
# Answer:  The prince is a character in a fairy tale called "The Princess and the Pea." The prince is searching for a true princess, and he believes he has found her in a young woman who can feel the pea under twenty mattresses. However, it is later revealed that the young woman is not a princess, but a clever and resourceful commoner named Ella. The prince falls in love with Ella and they live happily ever after.
#
#
# -------------------
# LangChain/RAG APPLIED OVER (((DeepSeek R1))):
# Question: Who is the prince?
# Answer:  The prince is the little prince.
